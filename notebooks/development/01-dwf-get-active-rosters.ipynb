# %%
import pandas as pd
import glob
import requests
from bs4 import BeautifulSoup
import os

somelist=[]
for week_no in range(1,3):
    
    url = f'https://theaudl.com/league/news/2019-audl-active-rosters-week-{week_no}'
    result = requests.get(url)
    
    soup = BeautifulSoup(result.text,'lxml')
    
    teams = [team.text for team in soup.find_all('h2')[:-1]]
    active_players = [players.text for players in soup.find_all('p') if len(players.text) > 250]
    somelist+=[{'Year':2019,'Week':week_no, 'Team':t,'Actives':aps.replace('\n','; ')} for t,aps in zip(teams, active_players)]
        
audlactive = pd.DataFrame(somelist)#,columns=['Teamname','Players'])
audlactive.to_csv('../../data/teams/active_rosters.csv')
audlactive
# Out:
#                                               Actives                    Team  \
# 0   Sam Batson; Sun Choi; Karl Ekwurtzel; Brett Hu...          Atlanta Hustle
# 1   Matthew Bennett; Michael Cramer; Chase Cunning...              Austin Sol
# 2   Matthew Armour; Noah Chambers; Joel Clutton; A...       Dallas Roughnecks
# 3   Tyler Bacon; Tim Beatty; Kyle Conniff; Alex Dr...    Los Angeles Aviators
# 4   Kiron Allen; Jacob Fairfax; Henry Fisher; Misc...          Raleigh Flyers
# 5   Nathan Bridges; Travis Dunn; Sam Fontaine; Wes...      San Diego Growlers
# 6   Chuck Cao; Steven Chang; Matt Crawford; Antoin...        San Jose Spiders
# 7   Jesse Bolton; Jay Boychuk; Jack Brown; Mark Bu...        Seattle Cascades
# 8   Craig Anderson; Alex Bullock; Adam Carr; Ryan ...       Tampa Bay Cannons
# 9   Zach Avello; Josh Bush; Sun Choi; Jason Crowe;...          Atlanta Hustle
# 10  Matthew Bennett; Mitch Bennett; Matt Bierschen...              Austin Sol
# ...

# %%
import glob
audl = pd.concat([pd.read_csv(i) for i in glob.glob('../../data/processed/2019/*csv')])
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-5-71114741836d> in <module>
#       1 import glob
# ----> 2 audl = pd.concat([pd.read_csv(i) for i in glob.glob('../../data/processed/2019/*csv')])
#
# <ipython-input-5-71114741836d> in <listcomp>(.0)
#       1 import glob
# ----> 2 audl = pd.concat([pd.read_csv(i) for i in glob.glob('../../data/processed/2019/*csv')])
#
# ...

# %%
# for players in soup.find_all('p'):
#     if len(players.text) > 250:
#         print(players.text)

# for team in soup.find_all('h2')[:-1]:
#     print(team.text)
